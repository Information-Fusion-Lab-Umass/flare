# %%
import sys
sys.path.append('..')
from src import datagen
from src import engine
from src import utils
import yaml
from time import time
import os
import pandas as pd

# %%
table = pd.read_csv('../data/TADPOLE_D1_D2_proc_norm.csv')

# %%
def search_table(table,pid):
    '''
    Searches the table for the entri
Total people in test set who des corresponding to the pid. Checks if pid label is 'Dementia'.
    
    Returns True is 'Dementia'
    Returns False if not
    '''
    label = table[(table['PTID'] == pid) & (table['VISCODE'] =='bl')]['DX'].values[0]
    if label == 'Dementia' or label == 'AD':
        return True
    else:
        return False
    
def pid_convert(pid):
    '''
    Converts pids that in the form of integers to strings in the proper format
    
    Example: 012368 --> 001_S_2368
    
             12345  --> 001_S_2345
    '''
    p = pid.item()
    if 100000 < p < 1000000:
        p = '0'+str(p)[:2] + '_S_' + str(p)[2:]
    elif p < 100000 :
        p = '00' + str(p)[:1] + '_S_' + str(p)[1:]
    else:
        p = str(p)[:3] + '_S_' + str(p)[3:]
    return p

class Trajectory_Stats:
    def __init__(self, pid, y, y_pred, trajectory_id):
        self.pid = pid
        self.y = y
        _, self.y_pred = y_pred.max(0) #check this to make sure it's not different from argmax
        
        self.trajectory_id = trajectory_id
    
    def print_self(self):
        print('PID: ', self.pid)
        print('label: ', self.y)
        print('prediction: ', self.y_pred)
        print('trajectory_id: ', self.trajectory_id)

class Cascade:
    def __init__(self, trajectories):
        '''
        A cascade is a series of trajectories from a single patient used for tabulating results for
        AD transition detection at the patient level.
        '''
        self.trajectories = trajectories
        self.
        for t in trajectories
      
        flag = 0
        
        #TODO: Check Baseline label
        
        # Record the index where the transition occurs in ground truth
        for t in trajectories:
            if(t.y == 2):
                flag = 1
                self.transition_true = t.trajectory_id[-1]
                break
                
        if flag == 0:
            self.transition_true = -1
            
        flag = 0
        
        # Record the index where the transition occurs in FLARe
        for t in trajectories:
            if(t.y_pred == 2):
                flag = 1
                self.transition_flare = t.trajectory_id[-1]
                break
                
        if flag == 0:
            self.transition_flare = -1
           
        # Check for false positives. If transition true = -1, then the patient never develops AD
        if(self.transition_true == -1):
            self.type = 'No AD'
            if(self.transition_flare != -1):
                self.FP = True
            else:
                self.FP = False
        else:
            self.type = 'AD'
            if(self.transition_flare == -1):
                self.FN = True
            else:
                self.FN = False
                self.diff = self.transition_flare - self.transition_true
                
    def print_self(self):
        print('True Transition: ',self.transition_true)
        print('Predicted Transition: ',self.transition_flare)
        
        print('Trajectory Type: ', self.type)
        
        if(self.transition_flare > 0 and self.transition_true > 0):
            print('Difference in prediction time from ground truth: ', self.diff)
        print('Trajectories', self.trajectories)

# %%
with open('../data/stats.pickle','rb') as f:
    output = pickle.load(f)

# %%
def gen_patient_dict(val_dict_T):
    patients = {}
    num_entries = len(val_dict_T['pid'])
    print(num_entries)
    with open('../data/pids.pickle','rb') as f: # use ../data/patient_List_test.txt
        unique_pids = pickle.load(f)
    patients = {}
    
    # initialize patient dict
    for x in unique_pids:
        patients[x] = []
    
    for i in range(num_entries):
        pid = pid_convert(val_dict_T['pid'][i])
        temp_traj = Trajectory_Stats(pid, val_dict_T['y'][i],val_dict_T['y_pred'][i],val_dict_T['trajectory_id'][i])
        patients[pid].append(temp_traj)
    return patients

# %%
def create_cascade(patients, T):
    '''
    Takes a patient dict as input and creates cascades for a certain value of 'T'
    '''
    final = {}
    cascades = {}
    for key in patients:
        # sort Trajectory objects by lexicographical order of their trajectory id's
        patients[key].sort(key=lambda k: k.trajectory_id.tolist())
        final[key] = []
        for t in patients[key]:
            if(T == 1):
                if t.trajectory_id[0] == 0 and len(patients[key]) > 1:
                    final[key].append(t)
            elif (T == 2):
                if t.trajectory_id[0] == 0 and t.trajectory_id[1] == 1 and len(patients[key]) > 2:
                    final[key].append(t)
         
    for key in final.keys():
        cascades[key] = Cascade(final[key])
    return cascades

# %%
def print_counts(cascades, T):
    '''
    Takes a dict of cascades as input and prints out counts
    '''
    counts = [0]*8
    FN = 0
    FP = 0
    total_no_ad = 0
    first_visit = 0
    developed = 0
    already_ad = 0
    for key in cascades.keys():
        cascade = cascades[key]
        print(cascade.print_self())
        if cascade.type == 'AD':
            if(not cascade.FN):
                if(cascade.trajectories[T-1].y == 2):
                    if(not search_table(table,key)):
                        developed += 1
                        counts[cascade.diff + 3] += 1
                    else:
                        already_ad += 1
                else:
                    developed += 1
                    counts[cascade.diff + 3] += 1
            else:
                developed += 1
                FN += 1
        if cascade.type == 'No AD':
            total_no_ad += 1
            if cascade.FP:
                FP += 1
    print('Predicted within... index 2 corresponds to -1',counts)
    print('False Negatives',FN)
    print("Total people in test set who didn't develop AD",total_no_ad)
    print('... and of those people the number of False Positives',FP)
    print("Total people who already had AD in the first visit", already_ad)
    total = np.sum(counts) + FN + FP + total_no_ad + already_ad + first_visit
    print("Total people who developed AD:", developed)
    print("Total people", total)

# %%
#Usage example
T = 1
patients = gen_patient_dict(output[T-1])

patients[list(patients.keys())[0]][0].print_self()
# Out:
# 3489
# PID:  002_S_0729
# label:  tensor(2.)
# prediction:  tensor(2)
# trajectory_id:  tensor([4, 5])

# %%
cascades = create_cascade(patients,T)
print_counts(cascades,T)
# Out:
# True Transition:  tensor(2)
# Predicted Transition:  tensor(2)
# Trajectory Type:  AD
# Difference in prediction time from ground truth:  tensor(0)
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c3e06d7f0>, <__main__.Trajectory_Stats object at 0x7f7c3d3dd550>, <__main__.Trajectory_Stats object at 0x7f7c41ee49b0>, <__main__.Trajectory_Stats object at 0x7f7c41f448d0>, <__main__.Trajectory_Stats object at 0x7f7c3ce997b8>]
# None
# True Transition:  tensor(3)
# Predicted Transition:  tensor(2)
# Trajectory Type:  AD
# Difference in prediction time from ground truth:  tensor(-1)
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c41b97198>, <__main__.Trajectory_Stats object at 0x7f7c3d62e160>, <__main__.Trajectory_Stats object at 0x7f7c3cde3ba8>, <__main__.Trajectory_Stats object at 0x7f7c3ce99668>, <__main__.Trajectory_Stats object at 0x7f7c3d716be0>]
# None
# True Transition:  -1
# Predicted Transition:  -1
# Trajectory Type:  No AD
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c41c3ba58>, <__main__.Trajectory_Stats object at 0x7f7c4185d080>, <__main__.Trajectory_Stats object at 0x7f7c3d62f128>, <__main__.Trajectory_Stats object at 0x7f7c3d794048>, <__main__.Trajectory_Stats object at 0x7f7c3ce1c9b0>]
# None
# True Transition:  -1
# Predicted Transition:  -1
# Trajectory Type:  No AD
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c3ce03dd8>, <__main__.Trajectory_Stats object at 0x7f7c4004c160>, <__main__.Trajectory_Stats object at 0x7f7c404f97f0>, <__main__.Trajectory_Stats object at 0x7f7c3cde3a20>]
# None
# True Transition:  -1
# Predicted Transition:  -1
# Trajectory Type:  No AD
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c41a71748>, <__main__.Trajectory_Stats object at 0x7f7c4004cd30>, <__main__.Trajectory_Stats object at 0x7f7c4185dba8>, <__main__.Trajectory_Stats object at 0x7f7c3de5f630>]
# None
# True Transition:  tensor(5)
# Predicted Transition:  tensor(5)
# Trajectory Type:  AD
# Difference in prediction time from ground truth:  tensor(0)
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c401ca470>, <__main__.Trajectory_Stats object at 0x7f7c403be710>, <__main__.Trajectory_Stats object at 0x7f7c41b23080>, <__main__.Trajectory_Stats object at 0x7f7c4004c748>, <__main__.Trajectory_Stats object at 0x7f7c41b23198>]
# None
# True Transition:  -1
# Predicted Transition:  -1
# Trajectory Type:  No AD
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c4185dc88>, <__main__.Trajectory_Stats object at 0x7f7c4185d908>]
# None
# True Transition:  -1
# Predicted Transition:  -1
# Trajectory Type:  No AD
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c41c35b38>, <__main__.Trajectory_Stats object at 0x7f7c418f7a20>, <__main__.Trajectory_Stats object at 0x7f7c3ce1c198>, <__main__.Trajectory_Stats object at 0x7f7c419f7860>, <__main__.Trajectory_Stats object at 0x7f7c3ce84a90>]
# None
# True Transition:  tensor(4)
# Predicted Transition:  tensor(4)
# Trajectory Type:  AD
# Difference in prediction time from ground truth:  tensor(0)
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c3d17bf60>, <__main__.Trajectory_Stats object at 0x7f7c3dc1a160>, <__main__.Trajectory_Stats object at 0x7f7c403be4e0>, <__main__.Trajectory_Stats object at 0x7f7c3dd3c8d0>]
# None
# True Transition:  tensor(1)
# Predicted Transition:  tensor(1)
# Trajectory Type:  AD
# Difference in prediction time from ground truth:  tensor(0)
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c3d3e3e80>, <__main__.Trajectory_Stats object at 0x7f7c3da4f8d0>, <__main__.Trajectory_Stats object at 0x7f7c418f7438>, <__main__.Trajectory_Stats object at 0x7f7c3fdf8358>]
# None
# True Transition:  -1
# Predicted Transition:  -1
# Trajectory Type:  No AD
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c3da4f630>, <__main__.Trajectory_Stats object at 0x7f7c41947c18>, <__main__.Trajectory_Stats object at 0x7f7c403d8630>, <__main__.Trajectory_Stats object at 0x7f7c3d716f28>, <__main__.Trajectory_Stats object at 0x7f7c3cddca58>]
# None
# True Transition:  tensor(2)
# Predicted Transition:  tensor(2)
# Trajectory Type:  AD
# Difference in prediction time from ground truth:  tensor(0)
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c41eb0ef0>, <__main__.Trajectory_Stats object at 0x7f7c41f44400>]
# None
# True Transition:  -1
# Predicted Transition:  -1
# Trajectory Type:  No AD
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c3de127b8>, <__main__.Trajectory_Stats object at 0x7f7c3d9f9c18>, <__main__.Trajectory_Stats object at 0x7f7c3da57160>, <__main__.Trajectory_Stats object at 0x7f7c3d3e3240>, <__main__.Trajectory_Stats object at 0x7f7c41947f60>]
# None
# True Transition:  tensor(1)
# Predicted Transition:  tensor(1)
# Trajectory Type:  AD
# Difference in prediction time from ground truth:  tensor(0)
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c3cd229e8>, <__main__.Trajectory_Stats object at 0x7f7c3ce03828>]
# None
# True Transition:  -1
# Predicted Transition:  -1
# Trajectory Type:  No AD
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c403d8ac8>, <__main__.Trajectory_Stats object at 0x7f7c3dd9da90>, <__main__.Trajectory_Stats object at 0x7f7c41b23be0>, <__main__.Trajectory_Stats object at 0x7f7c3d3ddc50>]
# None
# True Transition:  -1
# Predicted Transition:  -1
# Trajectory Type:  No AD
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c419f7fd0>, <__main__.Trajectory_Stats object at 0x7f7c3dc1a940>, <__main__.Trajectory_Stats object at 0x7f7c3d3dd0f0>, <__main__.Trajectory_Stats object at 0x7f7c3d2e5be0>]
# None
# True Transition:  tensor(1)
# Predicted Transition:  tensor(1)
# Trajectory Type:  AD
# Difference in prediction time from ground truth:  tensor(0)
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c41eb00b8>, <__main__.Trajectory_Stats object at 0x7f7c3dc1a320>, <__main__.Trajectory_Stats object at 0x7f7c41b23cf8>, <__main__.Trajectory_Stats object at 0x7f7c41c35048>]
# None
# True Transition:  tensor(2)
# Predicted Transition:  tensor(1)
# Trajectory Type:  AD
# Difference in prediction time from ground truth:  tensor(-1)
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c3d070470>, <__main__.Trajectory_Stats object at 0x7f7c4008d978>, <__main__.Trajectory_Stats object at 0x7f7c41acdb00>, <__main__.Trajectory_Stats object at 0x7f7c3dd3c438>, <__main__.Trajectory_Stats object at 0x7f7c3da4f860>]
# None
# True Transition:  -1
# Predicted Transition:  -1
# Trajectory Type:  No AD
# Trajectories []
# None
# True Transition:  -1
# Predicted Transition:  -1
# Trajectory Type:  No AD
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c3debd550>, <__main__.Trajectory_Stats object at 0x7f7c404a0be0>, <__main__.Trajectory_Stats object at 0x7f7c41b23780>, <__main__.Trajectory_Stats object at 0x7f7c3debd908>]
# None
# True Transition:  -1
# Predicted Transition:  -1
# Trajectory Type:  No AD
# Trajectories []
# None
# True Transition:  -1
# Predicted Transition:  -1
# Trajectory Type:  No AD
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c41eb06d8>, <__main__.Trajectory_Stats object at 0x7f7c3d9f9128>, <__main__.Trajectory_Stats object at 0x7f7c41c3b588>, <__main__.Trajectory_Stats object at 0x7f7c404f9a20>, <__main__.Trajectory_Stats object at 0x7f7c3d070ef0>]
# None
# True Transition:  -1
# Predicted Transition:  -1
# Trajectory Type:  No AD
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c3d3dd5f8>, <__main__.Trajectory_Stats object at 0x7f7c41acd0b8>]
# None
# True Transition:  -1
# Predicted Transition:  -1
# Trajectory Type:  No AD
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c3dc8a908>, <__main__.Trajectory_Stats object at 0x7f7c3e06dac8>, <__main__.Trajectory_Stats object at 0x7f7c41ed8860>, <__main__.Trajectory_Stats object at 0x7f7c3dce89e8>, <__main__.Trajectory_Stats object at 0x7f7c42228b70>]
# None
# True Transition:  tensor(4)
# Predicted Transition:  tensor(3)
# Trajectory Type:  AD
# Difference in prediction time from ground truth:  tensor(-1)
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c3dd9deb8>, <__main__.Trajectory_Stats object at 0x7f7c3e010d68>, <__main__.Trajectory_Stats object at 0x7f7c3d1258d0>, <__main__.Trajectory_Stats object at 0x7f7c3d070dd8>, <__main__.Trajectory_Stats object at 0x7f7c42228208>]
# None
# True Transition:  tensor(1)
# Predicted Transition:  tensor(1)
# Trajectory Type:  AD
# Difference in prediction time from ground truth:  tensor(0)
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c3d9046d8>, <__main__.Trajectory_Stats object at 0x7f7c3d35d550>, <__main__.Trajectory_Stats object at 0x7f7c3ce03e10>, <__main__.Trajectory_Stats object at 0x7f7c3debddd8>]
# None
# True Transition:  -1
# Predicted Transition:  -1
# Trajectory Type:  No AD
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c3fdd4630>, <__main__.Trajectory_Stats object at 0x7f7c3d125550>, <__main__.Trajectory_Stats object at 0x7f7c3ce84ba8>, <__main__.Trajectory_Stats object at 0x7f7c4008d9e8>, <__main__.Trajectory_Stats object at 0x7f7c3dc1a7b8>]
# None
# True Transition:  tensor(5)
# Predicted Transition:  tensor(5)
# Trajectory Type:  AD
# Difference in prediction time from ground truth:  tensor(0)
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c3d1e4cc0>, <__main__.Trajectory_Stats object at 0x7f7c3da570f0>, <__main__.Trajectory_Stats object at 0x7f7c41eb0128>]
# None
# True Transition:  -1
# Predicted Transition:  -1
# Trajectory Type:  No AD
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c3ce99f28>, <__main__.Trajectory_Stats object at 0x7f7c3d904c88>, <__main__.Trajectory_Stats object at 0x7f7c3cde3d68>, <__main__.Trajectory_Stats object at 0x7f7c3fdd44a8>]
# None
# True Transition:  -1
# Predicted Transition:  -1
# Trajectory Type:  No AD
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c3d125198>, <__main__.Trajectory_Stats object at 0x7f7c404f9518>, <__main__.Trajectory_Stats object at 0x7f7c3cddc588>, <__main__.Trajectory_Stats object at 0x7f7c3cbe8eb8>, <__main__.Trajectory_Stats object at 0x7f7c3dd9de48>]
# None
# True Transition:  -1
# Predicted Transition:  -1
# Trajectory Type:  No AD
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c3fdf86a0>, <__main__.Trajectory_Stats object at 0x7f7c41947358>, <__main__.Trajectory_Stats object at 0x7f7c40393390>, <__main__.Trajectory_Stats object at 0x7f7c3ce1ca90>]
# None
# True Transition:  tensor(1)
# Predicted Transition:  tensor(1)
# Trajectory Type:  AD
# Difference in prediction time from ground truth:  tensor(0)
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c4185d710>, <__main__.Trajectory_Stats object at 0x7f7c3d0709e8>, <__main__.Trajectory_Stats object at 0x7f7c3ce1cac8>]
# None
# True Transition:  -1
# Predicted Transition:  -1
# Trajectory Type:  No AD
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c401508d0>, <__main__.Trajectory_Stats object at 0x7f7c3dce8048>]
# None
# True Transition:  -1
# Predicted Transition:  -1
# Trajectory Type:  No AD
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c3cd22080>, <__main__.Trajectory_Stats object at 0x7f7c3d7942e8>, <__main__.Trajectory_Stats object at 0x7f7c3de5fef0>, <__main__.Trajectory_Stats object at 0x7f7c509ed438>, <__main__.Trajectory_Stats object at 0x7f7c3dd3c6d8>]
# None
# True Transition:  tensor(4)
# Predicted Transition:  -1
# Trajectory Type:  AD
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c3
]
# None
# True Transition:  -1
# Predicted Transition:  -1
# Trajectory Type:  No AD
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c3de15048>, <__main__.Trajectory_Stats object at 0x7f7c3d9f96a0>, <__main__.Trajectory_Stats object at 0x7f7c41d98208>, <__main__.Trajectory_Stats object at 0x7f7c3debd2e8>, <__main__.Trajectory_Stats object at 0x7f7c3d17bcc0>]
# None
# True Transition:  -1
# Predicted Transition:  -1
# Trajectory Type:  No AD
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c3d716940>, <__main__.Trajectory_Stats object at 0x7f7c41eb0940>, <__main__.Trajectory_Stats object at 0x7f7c3da57358>]
# None
# True Transition:  -1
# Predicted Transition:  -1
# Trajectory Type:  No AD
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c403be780>, <__main__.Trajectory_Stats object at 0x7f7c41f44cf8>, <__main__.Trajectory_Stats object at 0x7f7c403d8c88>, <__main__.Trajectory_Stats object at 0x7f7c3d9f9048>, <__main__.Trajectory_Stats object at 0x7f7c3dc8a748>]
# None
# True Transition:  tensor(2)
# Predicted Transition:  tensor(1)
# Trajectory Type:  AD
# Difference in prediction time from ground truth:  tensor(-1)
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c3d9043c8>, <__main__.Trajectory_Stats object at 0x7f7c404a8588>, <__main__.Trajectory_Stats object at 0x7f7c40150390>, <__main__.Trajectory_Stats object at 0x7f7c3d9f9978>, <__main__.Trajectory_Stats object at 0x7f7c41eb0a20>]
# None
# True Transition:  tensor(1)
# Predicted Transition:  tensor(1)
# Trajectory Type:  AD
# Difference in prediction time from ground truth:  tensor(0)
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c3cd22dd8>, <__main__.Trajectory_Stats object at 0x7f7c42228be0>, <__main__.Trajectory_Stats object at 0x7f7c42228240>, <__main__.Trajectory_Stats object at 0x7f7c401ca7f0>]
# None
# True Transition:  tensor(4)
# Predicted Transition:  -1
# Trajectory Type:  AD
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c41b239e8>, <__main__.Trajectory_Stats object at 0x7f7c3dc8ac88>, <__main__.Trajectory_Stats object at 0x7f7c3d35d978>, <__main__.Trajectory_Stats object at 0x7f7c3cde3400>]
# None
# True Transition:  -1
# Predicted Transition:  -1
# Trajectory Type:  No AD
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c404f95c0>, <__main__.Trajectory_Stats object at 0x7f7c42228898>, <__main__.Trajectory_Stats object at 0x7f7c403be748>]
# None
# True Transition:  tensor(3)
# Predicted Transition:  tensor(2)
# Trajectory Type:  AD
# Difference in prediction time from ground truth:  tensor(-1)
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c3ce84860>, <__main__.Trajectory_Stats object at 0x7f7c41947748>, <__main__.Trajectory_Stats object at 0x7f7c403d8470>, <__main__.Trajectory_Stats object at 0x7f7c3d75da90>, <__main__.Trajectory_Stats object at 0x7f7c3de15b38>]
# None
# True Transition:  -1
# Predicted Transition:  -1
# Trajectory Type:  No AD
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c4185d438>, <__main__.Trajectory_Stats object at 0x7f7c3fe8bda0>, <__main__.Trajectory_Stats object at 0x7f7c3dd3c588>, <__main__.Trajectory_Stats object at 0x7f7c3d35df60>]
# None
# True Transition:  -1
# Predicted Transition:  -1
# Trajectory Type:  No AD
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c41c352b0>, <__main__.Trajectory_Stats object at 0x7f7c3cd22550>, <__main__.Trajectory_Stats object at 0x7f7c3d070588>, <__main__.Trajectory_Stats object at 0x7f7c41c35f60>]
# None
# True Transition:  -1
# Predicted Transition:  -1
# Trajectory Type:  No AD
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c403d82e8>, <__main__.Trajectory_Stats object at 0x7f7c41b23908>, <__main__.Trajectory_Stats object at 0x7f7c3de15ac8>, <__main__.Trajectory_Stats object at 0x7f7c41acd198>]
# None
# True Transition:  tensor(4)
# Predicted Transition:  tensor(3)
# Trajectory Type:  AD
# Difference in prediction time from ground truth:  tensor(-1)
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c3d391b00>, <__main__.Trajectory_Stats object at 0x7f7c403d8128>, <__main__.Trajectory_Stats object at 0x7f7c3d62ec88>, <__main__.Trajectory_Stats object at 0x7f7c41ee4e80>, <__main__.Trajectory_Stats object at 0x7f7c3d62f2b0>]
# None
# True Transition:  tensor(4)
# Predicted Transition:  tensor(4)
# Trajectory Type:  AD
# Difference in prediction time from ground truth:  tensor(0)
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c41b230b8>, <__main__.Trajectory_Stats object at 0x7f7c4057f2e8>, <__main__.Trajectory_Stats object at 0x7f7c3ce1c0b8>, <__main__.Trajectory_Stats object at 0x7f7c3dd9d828>]
# None
# True Transition:  tensor(1)
# Predicted Transition:  tensor(1)
# Trajectory Type:  AD
# Difference in prediction time from ground truth:  tensor(0)
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c3de12a90>, <__main__.Trajectory_Stats object at 0x7f7c41947a58>, <__main__.Trajectory_Stats object at 0x7f7c3d070ac8>, <__main__.Trajectory_Stats object at 0x7f7c400cac88>]
# None
# True Transition:  tensor(3)
# Predicted Transition:  tensor(2)
# Trajectory Type:  AD
# Difference in prediction time from ground truth:  tensor(-1)
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c41ee4dd8>, <__main__.Trajectory_Stats object at 0x7f7c3dd9da20>, <__main__.Trajectory_Stats object at 0x7f7c3d904b38>, <__main__.Trajectory_Stats object at 0x7f7c41c56e80>, <__main__.Trajectory_Stats object at 0x7f7c403d8710>]
# None
# True Transition:  -1
# Predicted Transition:  -1
# Trajectory Type:  No AD
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c3dd3cdd8>, <__main__.Trajectory_Stats object at 0x7f7c3d3d5518>, <__main__.Trajectory_Stats object at 0x7f7c3d3e3320>, <__main__.Trajectory_Stats object at 0x7f7c3d0709b0>, <__main__.Trajectory_Stats object at 0x7f7c403937b8>]
# None
# True Transition:  tensor(1)
# Predicted Transition:  tensor(1)
# Trajectory Type:  AD
# Difference in prediction time from ground truth:  tensor(0)
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c3d62f860>, <__main__.Trajectory_Stats object at 0x7f7c4004c9b0>, <__main__.Trajectory_Stats object at 0x7f7c4018f3c8>, <__main__.Trajectory_Stats object at 0x7f7c41c56e48>]
# None
# True Transition:  -1
# Predicted Transition:  -1
# Trajectory Type:  No AD
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c3d125278>, <__main__.Trajectory_Stats object at 0x7f7c3dd3c2e8>, <__main__.Trajectory_Stats object at 0x7f7c3cddc470>, <__main__.Trajectory_Stats object at 0x7f7c3d17bf98>, <__main__.Trajectory_Stats object at 0x7f7c3d391dd8>]
# None
# True Transition:  -1
# Predicted Transition:  -1
# Trajectory Type:  No AD
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c41eb0cf8>, <__main__.Trajectory_Stats object at 0x7f7c401ca9e8>]
# None
# True Transition:  -1
# Predicted Transition:  -1
# Trajectory Type:  No AD
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c3ce1c588>, <__main__.Trajectory_Stats object at 0x7f7c3dc1ab70>, <__main__.Trajectory_Stats object at 0x7f7c3dd3ccc0>, <__main__.Trajectory_Stats object at 0x7f7c3d716f98>, <__main__.Trajectory_Stats object at 0x7f7c41d989e8>]
# None
# True Transition:  -1
# Predicted Transition:  -1
# Trajectory Type:  No AD
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c3e010128>, <__main__.Trajectory_Stats object at 0x7f7c3ce03198>, <__main__.Trajectory_Stats object at 0x7f7c41b97160>, <__main__.Trajectory_Stats object at 0x7f7c3ce1c908>]
# None
# True Transition:  -1
# Predicted Transition:  -1
# Trajectory Type:  No AD
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c41c359e8>, <__main__.Trajectory_Stats object at 0x7f7c41b23ef0>, <__main__.Trajectory_Stats object at 0x7f7c3ce84358>, <__main__.Trajectory_Stats object at 0x7f7c41c35748>, <__main__.Trajectory_Stats object at 0x7f7c404a0e48>]
# None
# True Transition:  tensor(1)
# Predicted Transition:  tensor(1)
# Trajectory Type:  AD
# Difference in prediction time from ground truth:  tensor(0)
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c3d35dbe0>, <__main__.Trajectory_Stats object at 0x7f7c41eb0860>, <__main__.Trajectory_Stats object at 0x7f7c3d75d860>]
# None
# True Transition:  tensor(2)
# Predicted Transition:  tensor(2)
# Trajectory Type:  AD
# Difference in prediction time from ground truth:  tensor(0)
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c418f7da0>, <__main__.Trajectory_Stats object at 0x7f7c3ce1c898>, <__main__.Trajectory_Stats object at 0x7f7c41b97f60>, <__main__.Trajectory_Stats object at 0x7f7c3de5f0b8>]
# None
# True Transition:  -1
# Predicted Transition:  -1
# Trajectory Type:  No AD
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c41b977f0>, <__main__.Trajectory_Stats object at 0x7f7c3dc1a1d0>, <__main__.Trajectory_Stats object at 0x7f7c3dd3cf60>, <__main__.Trajectory_Stats object at 0x7f7c3d62ea58>]
# None
# True Transition:  -1
# Predicted Transition:  -1
# Trajectory Type:  No AD
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c3d3e3908>, <__main__.Trajectory_Stats object at 0x7f7c3ce84710>, <__main__.Trajectory_Stats object at 0x7f7c3d125c50>, <__main__.Trajectory_Stats object at 0x7f7c41947048>, <__main__.Trajectory_Stats object at 0x7f7c3d391748>]
# None
# True Transition:  -1
# Predicted Transition:  -1
# Trajectory Type:  No AD
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c4057f6d8>, <__main__.Trajectory_Stats object at 0x7f7c3dce8c18>]
# None
# True Transition:  -1
# Predicted Transition:  -1
# Trajectory Type:  No AD
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c418f7128>, <__main__.Trajectory_Stats object at 0x7f7c3d3e34a8>]
# None
# True Transition:  tensor(1)
# Predicted Transition:  tensor(1)
# Trajectory Type:  AD
# Difference in prediction time from ground truth:  tensor(0)
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c3d5ad3c8>, <__main__.Trajectory_Stats object at 0x7f7c3dc8a9b0>, <__main__.Trajectory_Stats object at 0x7f7c3dc8abe0>, <__main__.Trajectory_Stats object at 0x7f7c3dc1acc0>]
# None
# True Transition:  -1
# Predicted Transition:  -1
# Trajectory Type:  No AD
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c418f7c50>, <__main__.Trajectory_Stats object at 0x7f7c41c3bb38>, <__main__.Trajectory_Stats object at 0x7f7c40150780>, <__main__.Trajectory_Stats object at 0x7f7c41b97470>, <__main__.Trajectory_Stats object at 0x7f7c41d980b8>]
# None
# True Transition:  -1
# Predicted Transition:  -1
# Trajectory Type:  No AD
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c3dd3c908>, <__main__.Trajectory_Stats object at 0x7f7c3ce03748>, <__main__.Trajectory_Stats object at 0x7f7c3fe8bf98>, <__main__.Trajectory_Stats object at 0x7f7c3dd3c0f0>, <__main__.Trajectory_Stats object at 0x7f7c3debd9b0>]
# None
# True Transition:  tensor(2)
# Predicted Transition:  tensor(1)
# Trajectory Type:  AD
# Difference in prediction time from ground truth:  tensor(-1)
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c3de12160>, <__main__.Trajectory_Stats object at 0x7f7c3cd22908>, <__main__.Trajectory_Stats object at 0x7f7c3cddc5c0>, <__main__.Trajectory_Stats object at 0x7f7c4057fba8>, <__main__.Trajectory_Stats object at 0x7f7c3dc1aeb8>]
# None
# True Transition:  -1
# Predicted Transition:  -1
# Trajectory Type:  No AD
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c3d070400>, <__main__.Trajectory_Stats object at 0x7f7c404f9f60>, <__main__.Trajectory_Stats object at 0x7f7c3cfeef98>]
# None
# True Transition:  -1
# Predicted Transition:  -1
# Trajectory Type:  No AD
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c3de15e48>, <__main__.Trajectory_Stats object at 0x7f7c3de5f4a8>]
# None
# True Transition:  -1
# Predicted Transition:  -1
# Trajectory Type:  No AD
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c404f91d0>, <__main__.Trajectory_Stats object at 0x7f7c41947e80>, <__main__.Trajectory_Stats object at 0x7f7c3d070d30>, <__main__.Trajectory_Stats object at 0x7f7c404f9470>, <__main__.Trajectory_Stats object at 0x7f7c3cde3cc0>]
# None
# True Transition:  -1
# Predicted Transition:  -1
# Trajectory Type:  No AD
# Trajectories []
# None
# True Transition:  tensor(5)
# Predicted Transition:  -1
# Trajectory Type:  AD
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c41b23e80>, <__main__.Trajectory_Stats object at 0x7f7c41b23d30>, <__main__.Trajectory_Stats object at 0x7f7c4018f630>, <__main__.Trajectory_Stats object at 0x7f7c401cacc0>, <__main__.Trajectory_Stats object at 0x7f7c41b23390>]
# None
# True Transition:  -1
# Predicted Transition:  -1
# Trajectory Type:  No AD
# Trajectories []
# None
# True Transition:  tensor(2)
# Predicted Transition:  tensor(1)
# Trajectory Type:  AD
# Difference in prediction time from ground truth:  tensor(-1)
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c41c35518>, <__main__.Trajectory_Stats object at 0x7f7c41ee48d0>, <__main__.Trajectory_Stats object at 0x7f7c3cddc438>, <__main__.Trajectory_Stats object at 0x7f7c3dc1ac18>, <__main__.Trajectory_Stats object at 0x7f7c41947a20>]
# None
# True Transition:  -1
# Predicted Transition:  -1
# Trajectory Type:  No AD
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c3ce84780>, <__main__.Trajectory_Stats object at 0x7f7c3d391550>, <__main__.Trajectory_Stats object at 0x7f7c4057f400>, <__main__.Trajectory_Stats object at 0x7f7c3d9f98d0>, <__main__.Trajectory_Stats object at 0x7f7c3dc4cb38>]
# None
# True Transition:  -1
# Predicted Transition:  -1
# Trajectory Type:  No AD
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c404a0eb8>, <__main__.Trajectory_Stats object at 0x7f7c3e0100b8>, <__main__.Trajectory_Stats object at 0x7f7c3d62ec18>, <__main__.Trajectory_Stats object at 0x7f7c3d17be48>]
# None
# True Transition:  -1
# Predicted Transition:  -1
# Trajectory Type:  No AD
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c403d8e48>, <__main__.Trajectory_Stats object at 0x7f7c3dc8ae10>, <__main__.Trajectory_Stats object at 0x7f7c422284a8>, <__main__.Trajectory_Stats object at 0x7f7c3d35df28>]
# None
# True Transition:  -1
# Predicted Transition:  -1
# Trajectory Type:  No AD
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c3da4fd68>, <__main__.Trajectory_Stats object at 0x7f7c3da4f780>, <__main__.Trajectory_Stats object at 0x7f7c3d62f048>, <__main__.Trajectory_Stats object at 0x7f7c41947fd0>]
# None
# True Transition:  tensor(1)
# Predicted Transition:  tensor(1)
# Trajectory Type:  AD
# Difference in prediction time from ground truth:  tensor(0)
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c3d0705c0>, <__main__.Trajectory_Stats object at 0x7f7c41a71fd0>, <__main__.Trajectory_Stats object at 0x7f7c41873c88>, <__main__.Trajectory_Stats object at 0x7f7c41c77278>]
# None
# True Transition:  tensor(5)
# Predicted Transition:  -1
# Trajectory Type:  AD
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c404a0240>, <__main__.Trajectory_Stats object at 0x7f7c404f9fd0>, <__main__.Trajectory_Stats object at 0x7f7c4185df98>, <__main__.Trajectory_Stats object at 0x7f7c400ca630>, <__main__.Trajectory_Stats object at 0x7f7c41c35b70>]
# None
# True Transition:  tensor(3)
# Predicted Transition:  tensor(2)
# Trajectory Type:  AD
# Difference in prediction time from ground truth:  tensor(-1)
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c41b978d0>, <__main__.Trajectory_Stats object at 0x7f7c41f44dd8>, <__main__.Trajectory_Stats object at 0x7f7c3e010208>, <__main__.Trajectory_Stats object at 0x7f7c3dc1a550>, <__main__.Trajectory_Stats object at 0x7f7c3dd9d6a0>]
# None
# True Transition:  tensor(2)
# Predicted Transition:  tensor(2)
# Trajectory Type:  AD
# Difference in prediction time from ground truth:  tensor(0)
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c41c774e0>, <__main__.Trajectory_Stats object at 0x7f7c41947ac8>, <__main__.Trajectory_Stats object at 0x7f7c3da4f438>]
# None
# True Transition:  tensor(2)
# Predicted Transition:  tensor(2)
# Trajectory Type:  AD
# Difference in prediction time from ground truth:  tensor(0)
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c3d62fe48>, <__main__.Trajectory_Stats object at 0x7f7c419477f0>, <__main__.Trajectory_Stats object at 0x7f7c41b976d8>, <__main__.Trajectory_Stats object at 0x7f7c41b235f8>]
# None
# True Transition:  -1
# Predicted Transition:  -1
# Trajectory Type:  No AD
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c418f74e0>, <__main__.Trajectory_Stats object at 0x7f7c3dc1a400>, <__main__.Trajectory_Stats object at 0x7f7c3d904d30>, <__main__.Trajectory_Stats object at 0x7f7c418f7f98>, <__main__.Trajectory_Stats object at 0x7f7c41c35630>]
# None
# True Transition:  -1
# Predicted Transition:  -1
# Trajectory Type:  No AD
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c3dce8c88>, <__main__.Trajectory_Stats object at 0x7f7c3dd3cf98>, <__main__.Trajectory_Stats object at 0x7f7c3ce99b00>, <__main__.Trajectory_Stats object at 0x7f7c3d070668>]
# None
# True Transition:  -1
# Predicted Transition:  -1
# Trajectory Type:  No AD
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c41ee46d8>, <__main__.Trajectory_Stats object at 0x7f7c41c56390>, <__main__.Trajectory_Stats object at 0x7f7c3d3ddb38>]
# None
# True Transition:  -1
# Predicted Transition:  -1
# Trajectory Type:  No AD
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c4185d358>, <__main__.Trajectory_Stats object at 0x7f7c3dc8a198>, <__main__.Trajectory_Stats object at 0x7f7c3d125320>]
# None
# True Transition:  tensor(1)
# Predicted Transition:  tensor(1)
# Trajectory Type:  AD
# Difference in prediction time from ground truth:  tensor(0)
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c403be240>, <__main__.Trajectory_Stats object at 0x7f7c403be630>, <__main__.Trajectory_Stats object at 0x7f7c41c77668>, <__main__.Trajectory_Stats object at 0x7f7c3d35d278>, <__main__.Trajectory_Stats object at 0x7f7c403d8f28>]
# None
# True Transition:  tensor(1)
# Predicted Transition:  tensor(1)
# Trajectory Type:  AD
# Difference in prediction time from ground truth:  tensor(0)
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c41ee4b00>, <__main__.Trajectory_Stats object at 0x7f7c404a8048>, <__main__.Trajectory_Stats object at 0x7f7c4018fac8>, <__main__.Trajectory_Stats object at 0x7f7c3dd9d048>]
# None
# True Transition:  -1
# Predicted Transition:  -1
# Trajectory Type:  No AD
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c41a451d0>, <__main__.Trajectory_Stats object at 0x7f7c400ca240>, <__main__.Trajectory_Stats object at 0x7f7c3d904630>, <__main__.Trajectory_Stats object at 0x7f7c3cd22e48>]
# None
# True Transition:  -1
# Predicted Transition:  -1
# Trajectory Type:  No AD
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c3de12c88>, <__main__.Trajectory_Stats object at 0x7f7c41c77e48>, <__main__.Trajectory_Stats object at 0x7f7c41c77160>, <__main__.Trajectory_Stats object at 0x7f7c403d89b0>, <__main__.Trajectory_Stats object at 0x7f7c3ce1c438>]
# None
# True Transition:  -1
# Predicted Transition:  -1
# Trajectory Type:  No AD
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c3d716f60>, <__main__.Trajectory_Stats object at 0x7f7c418f7dd8>]
# None
# True Transition:  -1
# Predicted Transition:  -1
# Trajectory Type:  No AD
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c
]
# None
# True Transition:  tensor(1)
# Predicted Transition:  tensor(1)
# Trajectory Type:  AD
# Difference in prediction time from ground truth:  tensor(0)
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c3d3d5128>, <__main__.Trajectory_Stats object at 0x7f7c3dd3c048>, <__main__.Trajectory_Stats object at 0x7f7c3dce8630>, <__main__.Trajectory_Stats object at 0x7f7c3de12c18>]
# None
# True Transition:  -1
# Predicted Transition:  -1
# Trajectory Type:  No AD
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c3d2e5470>, <__main__.Trajectory_Stats object at 0x7f7c403d80b8>, <__main__.Trajectory_Stats object at 0x7f7c403932e8>, <__main__.Trajectory_Stats object at 0x7f7c41eb09e8>]
# None
# True Transition:  tensor(1)
# Predicted Transition:  tensor(1)
# Trajectory Type:  AD
# Difference in prediction time from ground truth:  tensor(0)
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c41b23a90>, <__main__.Trajectory_Stats object at 0x7f7c404a0630>, <__main__.Trajectory_Stats object at 0x7f7c3d070518>, <__main__.Trajectory_Stats object at 0x7f7c41c3b6d8>]
# None
# True Transition:  tensor(3)
# Predicted Transition:  tensor(3)
# Trajectory Type:  AD
# Difference in prediction time from ground truth:  tensor(0)
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c403bea20>, <__main__.Trajectory_Stats object at 0x7f7c403d8b70>, <__main__.Trajectory_Stats object at 0x7f7c41873c50>, <__main__.Trajectory_Stats object at 0x7f7c41873d30>, <__main__.Trajectory_Stats object at 0x7f7c3d904e10>]
# None
# True Transition:  tensor(5)
# Predicted Transition:  tensor(5)
# Trajectory Type:  AD
# Difference in prediction time from ground truth:  tensor(0)
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c41c3bba8>, <__main__.Trajectory_Stats object at 0x7f7c3d35d2b0>, <__main__.Trajectory_Stats object at 0x7f7c41acd358>, <__main__.Trajectory_Stats object at 0x7f7c3dd9dc88>, <__main__.Trajectory_Stats object at 0x7f7c41f44f98>]
# None
# True Transition:  tensor(1)
# Predicted Transition:  tensor(1)
# Trajectory Type:  AD
# Difference in prediction time from ground truth:  tensor(0)
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c41eb07b8>, <__main__.Trajectory_Stats object at 0x7f7c41b97eb8>, <__main__.Trajectory_Stats object at 0x7f7c3dc4c940>, <__main__.Trajectory_Stats object at 0x7f7c404f9668>, <__main__.Trajectory_Stats object at 0x7f7c3dd3c5f8>]
# None
# True Transition:  tensor(1)
# Predicted Transition:  tensor(1)
# Trajectory Type:  AD
# Difference in prediction time from ground truth:  tensor(0)
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c3dd3c4e0>, <__main__.Trajectory_Stats object at 0x7f7c41a71438>, <__main__.Trajectory_Stats object at 0x7f7c4008d860>, <__main__.Trajectory_Stats object at 0x7f7c41c56c18>]
# None
# True Transition:  tensor(1)
# ...
# Trajectory Type:  AD
# Difference in prediction time from ground truth:  tensor(0)
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c400cab70>, <__main__.Trajectory_Stats object at 0x7f7c401ca898>]
# None
# True Transition:  -1
# Predicted Transition:  -1
# Trajectory Type:  No AD
# Trajectories []
# None
# True Transition:  -1
# Predicted Transition:  -1
# Trajectory Type:  No AD
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c3dd3cc18>, <__main__.Trajectory_Stats object at 0x7f7c41a71ac8>, <__main__.Trajectory_Stats object at 0x7f7c404a0a90>, <__main__.Trajectory_Stats object at 0x7f7c41b97dd8>, <__main__.Trajectory_Stats object at 0x7f7c3d9f9f60>]
# None
# True Transition:  -1
# Predicted Transition:  -1
# Trajectory Type:  No AD
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c401505c0>, <__main__.Trajectory_Stats object at 0x7f7c41ed8e80>, <__main__.Trajectory_Stats object at 0x7f7c41eb0f28>, <__main__.Trajectory_Stats object at 0x7f7c3d2e5588>, <__main__.Trajectory_Stats object at 0x7f7c41c77b38>]
# None
# True Transition:  -1
# Predicted Transition:  tensor(2)
# Trajectory Type:  No AD
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c3d2e5128>, <__main__.Trajectory_Stats object at 0x7f7c418f74a8>, <__main__.Trajectory_Stats object at 0x7f7c3ce1c6d8>, <__main__.Trajectory_Stats object at 0x7f7c3de15940>, <__main__.Trajectory_Stats object at 0x7f7c41ed8160>]
# None
# True Transition:  -1
# Predicted Transition:  -1
# Trajectory Type:  No AD
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c3d62e400>, <__main__.Trajectory_Stats object at 0x7f7c3dd3ce48>, <__main__.Trajectory_Stats object at 0x7f7c3dc4cc88>, <__main__.Trajectory_Stats object at 0x7f7c3e010748>, <__main__.Trajectory_Stats object at 0x7f7c419f7630>]
# None
# True Transition:  -1
# Predicted Transition:  -1
# Trajectory Type:  No AD
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c3d9f9710>, <__main__.Trajectory_Stats object at 0x7f7c3dd3c358>, <__main__.Trajectory_Stats object at 0x7f7c3dce8d30>, <__main__.Trajectory_Stats object at 0x7f7c3d125e80>, <__main__.Trajectory_Stats object at 0x7f7c41b97668>]
# None
# True Transition:  -1
# Predicted Transition:  -1
# Trajectory Type:  No AD
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c3d125ba8>, <__main__.Trajectory_Stats object at 0x7f7c41c35d30>, <__main__.Trajectory_Stats object at 0x7f7c403bed68>, <__main__.Trajectory_Stats object at 0x7f7c403d80f0>]
# None
# True Transition:  tensor(1)
# Predicted Transition:  tensor(1)
# Trajectory Type:  AD
# Difference in prediction time from ground truth:  tensor(0)
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c3de12b38>, <__main__.Trajectory_Stats object at 0x7f7c3d3ddcc0>, <__main__.Trajectory_Stats object at 0x7f7c3cd222e8>, <__main__.Trajectory_Stats object at 0x7f7c3d62fda0>, <__main__.Trajectory_Stats object at 0x7f7c3cd22400>]
# None
# True Transition:  tensor(1)
# Predicted Transition:  -1
# Trajectory Type:  AD
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c3ce1c390>, <__main__.Trajectory_Stats object at 0x7f7c4004c2b0>, <__main__.Trajectory_Stats object at 0x7f7c3d35d470>, <__main__.Trajectory_Stats object at 0x7f7c4185df28>]
# None
# True Transition:  tensor(1)
# Predicted Transition:  tensor(1)
# Trajectory Type:  AD
# Difference in prediction time from ground truth:  tensor(0)
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c41873ef0>, <__main__.Trajectory_Stats object at 0x7f7c41b23c88>]
# None
# True Transition:  -1
# Predicted Transition:  -1
# Trajectory Type:  No AD
# Trajectories []
# None
# True Transition:  tensor(3)
# Predicted Transition:  -1
# Trajectory Type:  AD
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c3d3dd4a8>, <__main__.Trajectory_Stats object at 0x7f7c3d070cf8>, <__main__.Trajectory_Stats object at 0x7f7c3dc8a4e0>, <__main__.Trajectory_Stats object at 0x7f7c403935c0>, <__main__.Trajectory_Stats object at 0x7f7c3d3d5940>]
# None
# True Transition:  tensor(1)
# Predicted Transition:  tensor(1)
# Trajectory Type:  AD
# Difference in prediction time from ground truth:  tensor(0)
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c3d35de10>, <__main__.Trajectory_Stats object at 0x7f7c3de15668>, <__main__.Trajectory_Stats object at 0x7f7c41c56588>]
# None
# True Transition:  tensor(1)
# Predicted Transition:  tensor(1)
# Trajectory Type:  AD
# Difference in prediction time from ground truth:  tensor(0)
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c42228470>, <__main__.Trajectory_Stats object at 0x7f7c403d8cf8>, <__main__.Trajectory_Stats object at 0x7f7c419f7b38>]
# None
# True Transition:  -1
# Predicted Transition:  -1
# Trajectory Type:  No AD
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c3d794278>, <__main__.Trajectory_Stats object at 0x7f7c404a0c88>, <__main__.Trajectory_Stats object at 0x7f7c4185d4a8>, <__main__.Trajectory_Stats object at 0x7f7c41c354a8>]
# None
# True Transition:  -1
# Predicted Transition:  -1
# Trajectory Type:  No AD
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c404f9c50>, <__main__.Trajectory_Stats object at 0x7f7c3d7167b8>, <__main__.Trajectory_Stats object at 0x7f7c41d989b0>, <__main__.Trajectory_Stats object at 0x7f7c3d1254e0>, <__main__.Trajectory_Stats object at 0x7f7c41c771d0>]
# None
# True Transition:  -1
# Predicted Transition:  -1
# Trajectory Type:  No AD
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c3ce84518>, <__main__.Trajectory_Stats object at 0x7f7c403d88d0>, <__main__.Trajectory_Stats object at 0x7f7c42228668>, <__main__.Trajectory_Stats object at 0x7f7c403d8668>, <__main__.Trajectory_Stats object at 0x7f7c3da575f8>]
# None
# True Transition:  tensor(1)
# Predicted Transition:  tensor(4)
# Trajectory Type:  AD
# Difference in prediction time from ground truth:  tensor(3)
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c3d2e5b70>, <__main__.Trajectory_Stats object at 0x7f7c3de15128>, <__main__.Trajectory_Stats object at 0x7f7c3d35d9e8>, <__main__.Trajectory_Stats object at 0x7f7c3da573c8>]
# None
# True Transition:  -1
# Predicted Transition:  -1
# Trajectory Type:  No AD
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c4185d9b0>, <__main__.Trajectory_Stats object at 0x7f7c41c3beb8>, <__main__.Trajectory_Stats object at 0x7f7c41acde10>, <__main__.Trajectory_Stats object at 0x7f7c42228588>]
# None
# True Transition:  tensor(1)
# Predicted Transition:  tensor(1)
# Trajectory Type:  AD
# Difference in prediction time from ground truth:  tensor(0)
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c3e010d30>, <__main__.Trajectory_Stats object at 0x7f7c40393d68>, <__main__.Trajectory_Stats object at 0x7f7c3e010f60>, <__main__.Trajectory_Stats object at 0x7f7c41b97a20>]
# None
# True Transition:  -1
# Predicted Transition:  -1
# Trajectory Type:  No AD
# Trajectories []
# None
# True Transition:  -1
# Predicted Transition:  -1
# Trajectory Type:  No AD
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c3d3dd208>, <__main__.Trajectory_Stats object at 0x7f7c3d125f28>]
# None
# True Transition:  tensor(1)
# Predicted Transition:  tensor(1)
# Trajectory Type:  AD
# Difference in prediction time from ground truth:  tensor(0)
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c3da4f898>, <__main__.Trajectory_Stats object at 0x7f7c41947390>, <__main__.Trajectory_Stats object at 0x7f7c3dc1afd0>, <__main__.Trajectory_Stats object at 0x7f7c41c56828>, <__main__.Trajectory_Stats object at 0x7f7c3cde30b8>]
# None
# True Transition:  -1
# Predicted Transition:  -1
# Trajectory Type:  No AD
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c3e06dfd0>, <__main__.Trajectory_Stats object at 0x7f7c3d75da20>, <__main__.Trajectory_Stats object at 0x7f7c403d8e10>, <__main__.Trajectory_Stats object at 0x7f7c3de157f0>, <__main__.Trajectory_Stats object at 0x7f7c3d391be0>]
# None
# True Transition:  tensor(1)
# Predicted Transition:  tensor(1)
# Trajectory Type:  AD
# Difference in prediction time from ground truth:  tensor(0)
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c3debd278>, <__main__.Trajectory_Stats object at 0x7f7c3cddc240>, <__main__.Trajectory_Stats object at 0x7f7c41b97cf8>, <__main__.Trajectory_Stats object at 0x7f7c3d3916a0>]
# None
# True Transition:  -1
# Predicted Transition:  tensor(5)
# Trajectory Type:  No AD
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c3dc4c3c8>, <__main__.Trajectory_Stats object at 0x7f7c4004c4a8>, <__main__.Trajectory_Stats object at 0x7f7c3dd3ceb8>, <__main__.Trajectory_Stats object at 0x7f7c41ed8438>, <__main__.Trajectory_Stats object at 0x7f7c3fdf8e10>]
# None
# True Transition:  -1
# Predicted Transition:  -1
# Trajectory Type:  No AD
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c3d3dd358>, <__main__.Trajectory_Stats object at 0x7f7c3dd9d710>]
# None
# True Transition:  -1
# Predicted Transition:  -1
# Trajectory Type:  No AD
# Trajectories []
# None
# True Transition:  tensor(1)
# Predicted Transition:  tensor(4)
# Trajectory Type:  AD
# Difference in prediction time from ground truth:  tensor(3)
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c41acdba8>, <__main__.Trajectory_Stats object at 0x7f7c3dd3c710>, <__main__.Trajectory_Stats object at 0x7f7c3d5739b0>, <__main__.Trajectory_Stats object at 0x7f7c3d3d5e48>, <__main__.Trajectory_Stats object at 0x7f7c3d3dd940>]
# None
# True Transition:  tensor(1)
# Predicted Transition:  tensor(1)
# Trajectory Type:  AD
# Difference in prediction time from ground truth:  tensor(0)
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c404a8390>, <__main__.Trajectory_Stats object at 0x7f7c3cfee400>, <__main__.Trajectory_Stats object at 0x7f7c403d8748>, <__main__.Trajectory_Stats object at 0x7f7c3e010dd8>, <__main__.Trajectory_Stats object at 0x7f7c422288d0>]
# None
# True Transition:  -1
# Predicted Transition:  -1
# Trajectory Type:  No AD
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c419f7400>, <__main__.Trajectory_Stats object at 0x7f7c3dc4c9b0>, <__main__.Trajectory_Stats object at 0x7f7c3fe8bc50>, <__main__.Trajectory_Stats object at 0x7f7c41f44ef0>, <__main__.Trajectory_Stats object at 0x7f7c3dd3ce10>]
# None
# True Transition:  -1
# Predicted Transition:  -1
# Trajectory Type:  No AD
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c3cd222b0>, <__main__.Trajectory_Stats object at 0x7f7c3e06ddd8>, <__main__.Trajectory_Stats object at 0x7f7c41947400>, <__main__.Trajectory_Stats object at 0x7f7c3d3d5358>, <__main__.Trajectory_Stats object at 0x7f7c41f443c8>]
# None
# True Transition:  -1
# Predicted Transition:  -1
# Trajectory Type:  No AD
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c3dc8a470>, <__main__.Trajectory_Stats object at 0x7f7c41ee4c18>, <__main__.Trajectory_Stats object at 0x7f7c3d35d0b8>, <__main__.Trajectory_Stats object at 0x7f7c41873240>, <__main__.Trajectory_Stats object at 0x7f7c3dd3cc50>]
# None
# True Transition:  -1
# Predicted Transition:  -1
# Trajectory Type:  No AD
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c3dc8a898>, <__main__.Trajectory_Stats object at 0x7f7c3cddc1d0>, <__main__.Trajectory_Stats object at 0x7f7c3dce8a20>, <__main__.Trajectory_Stats object at 0x7f7c41a71278>, <__main__.Trajectory_Stats object at 0x7f7c3fdd4b38>]
# None
# True Transition:  tensor(1)
# Predicted Transition:  tensor(1)
# Trajectory Type:  AD
# Difference in prediction time from ground truth:  tensor(0)
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c4185d748>, <__main__.Trajectory_Stats object at 0x7f7c41a41fd0>]
# None
# True Transition:  -1
# Predicted Transition:  -1
# Trajectory Type:  No AD
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c3d35dfd0>, <__main__.Trajectory_Stats object at 0x7f7c3e06da20>, <__main__.Trajectory_Stats object at 0x7f7c41ed82e8>, <__main__.Trajectory_Stats object at 0x7f7c3dce8b00>, <__main__.Trajectory_Stats object at 0x7f7c41c77710>]
# None
# True Transition:  tensor(5)
# Predicted Transition:  -1
# Trajectory Type:  AD
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c3d0702b0>, <__main__.Trajectory_Stats object at 0x7f7c404f9a58>, <__main__.Trajectory_Stats object at 0x7f7c3ce03e80>, <__main__.Trajectory_Stats object at 0x7f7c3d35d3c8>]
# None
# True Transition:  -1
# Predicted Transition:  -1
# Trajectory Type:  No AD
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c3dd3c4a8>, <__main__.Trajectory_Stats object at 0x7f7c403d86a0>, <__main__.Trajectory_Stats object at 0x7f7c42228358>]
# None
# True Transition:  -1
# Predicted Transition:  -1
# Trajectory Type:  No AD
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c400ca748>, <__main__.Trajectory_Stats object at 0x7f7c3d5ad7b8>, <__main__.Trajectory_Stats object at 0x7f7c404a0ba8>, <__main__.Trajectory_Stats object at 0x7f7c3d3dd7f0>]
# None
# True Transition:  -1
# Predicted Transition:  -1
# Trajectory Type:  No AD
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c3e010198>, <__main__.Trajectory_Stats object at 0x7f7c3cddc400>]
# None
# True Transition:  -1
# Predicted Transition:  -1
# Trajectory Type:  No AD
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c3d7f7940>, <__main__.Trajectory_Stats object at 0x7f7c41a717f0>, <__main__.Trajectory_Stats object at 0x7f7c3dc8af98>, <__main__.Trajectory_Stats object at 0x7f7c3cde32e8>]
# None
# True Transition:  -1
# Predicted Transition:  -1
# Trajectory Type:  No AD
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c3ce1c358>, <__main__.Trajectory_Stats object at 0x7f7c3d794400>, <__main__.Trajectory_Stats object at 0x7f7c3dce80b8>, <__main__.Trajectory_Stats object at 0x7f7c403930f0>]
# None
# True Transition:  -1
# Predicted Transition:  -1
# Trajectory Type:  No AD
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c3d9f9d68>, <__main__.Trajectory_Stats object at 0x7f7c3ce031d0>, <__main__.Trajectory_Stats object at 0x7f7c41c56080>, <__main__.Trajectory_Stats object at 0x7f7c41ed8320>]
# None
# True Transition:  -1
# Predicted Transition:  -1
# Trajectory Type:  No AD
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c3cbe84a8>, <__main__.Trajectory_Stats object at 0x7f7c3ce84dd8>, <__main__.Trajectory_Stats object at 0x7f7c403be8d0>, <__main__.Trajectory_Stats object at 0x7f7c41c3b7f0>, <__main__.Trajectory_Stats object at 0x7f7c3d35deb8>]
# None
# True Transition:  tensor(3)
# Predicted Transition:  tensor(3)
# Trajectory Type:  AD
# Difference in prediction time from ground truth:  tensor(0)
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c3d391828>, <__main__.Trajectory_Stats object at 0x7f7c40393860>, <__main__.Trajectory_Stats object at 0x7f7c404f9b38>, <__main__.Trajectory_Stats object at 0x7f7c3d35dcc0>]
# None
# True Transition:  tensor(2)
# Predicted Transition:  tensor(1)
# Trajectory Type:  AD
# Difference in prediction time from ground truth:  tensor(-1)
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c3debdfd0>, <__main__.Trajectory_Stats object at 0x7f7c40393dd8>, <__main__.Trajectory_Stats object at 0x7f7c41c3bc50>, <__main__.Trajectory_Stats object at 0x7f7c3de5f208>]
# None
# True Transition:  -1
# Predicted Transition:  -1
# Trajectory Type:  No AD
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c403d8160>, <__main__.Trajectory_Stats object at 0x7f7c3d2e55f8>, <__main__.Trajectory_Stats object at 0x7f7c41c3b198>]
# None
# True Transition:  -1
# Predicted Transition:  -1
# Trajectory Type:  No AD
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c41c56780>, <__main__.Trajectory_Stats object at 0x7f7c41c3b2e8>, <__main__.Trajectory_Stats object at 0x7f7c3d125080>, <__main__.Trajectory_Stats object at 0x7f7c3d3d55c0>]
# None
# True Transition:  -1
# Predicted Transition:  -1
# Trajectory Type:  No AD
# Trajectories [<__main__.Trajectory_Stats object at 0x7f7c3d3dd5c0>, <__main__.Trajectory_Stats object at 0x7f7c3d3d59e8>, <__main__.Trajectory_Stats object at 0x7f7c3cfee5f8>, <__main__.Trajectory_Stats object at 0x7f7c41ed8cc0>, <__main__.Trajectory_Stats object at 0x7f7c403d8a90>]
# None
# Predicted within... index 2 corresponds to -1 [0, 0, 18, 25, 0, 1, 1, 1]
# False Negatives 7
# Total people in test set who didn't develop AD 216
# ... and of those people the number of False Positives 6
# Total people who already had AD in the first visit 62
# Total people who developed AD: 53
# Total people 337
